# %%
# importing files and dataset
import numpy as np
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score

student_por = pd.read_csv(r'C:\Users\janha\Desktop\StudentPerformanceAnalysis\data\student-por.csv', sep=';')
student_mat = pd.read_csv(r'C:\Users\janha\Desktop\StudentPerformanceAnalysis\data\student-mat.csv', sep=';')

# %%
student_por.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
student_mat.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
traindata.dropna(inplace=True)
testdata.dropna(inplace=True)
data = pd.concat([traindata,testdata], axis=0)
data
# Out:
#     school sex   age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  18.0       U     GT3       A   4.0   4.0   at_home   teacher
# 1       GP   F  17.0       U     GT3       T   1.0   1.0   at_home     other
# 2       GP   F  15.0       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F  15.0       U     GT3       T   4.0   2.0    health  services
# 4       GP   F  16.0       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..   ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M  20.0       U     LE3       A   2.0   2.0  services  services
# 391     MS   M  17.0       U     LE3       T   3.0   1.0  services  services
# 392     MS   M  21.0       R     GT3       T   1.0   1.0     other     other
# 393     MS   M  18.0       R     LE3       T   3.0   2.0  services     other
# 394     MS   M  19.0       U     LE3       T   1.0   1.0     other   at_home
#
# ...

# %%
traindata.head()
# Out:
#   school sex   age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  18.0       U     GT3       A   4.0   4.0  at_home   teacher
# 1     GP   F  17.0       U     GT3       T   1.0   1.0  at_home     other
# 2     GP   F  15.0       U     LE3       T   1.0   1.0  at_home     other
# 3     GP   F  15.0       U     GT3       T   4.0   2.0   health  services
# 4     GP   F  16.0       U     GT3       T   3.0   3.0    other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences    G1    G2    G3
# 0  ...    4.0      3.0    4.0   1.0   1.0    3.0      4.0   0.0  11.0  11.0
# 1  ...    5.0      3.0    3.0   1.0   1.0    3.0      2.0   9.0  11.0  11.0
# 2  ...    4.0      3.0    2.0   2.0   3.0    3.0      6.0  12.0  13.0  12.0
# 3  ...    3.0      2.0    2.0   1.0   1.0    5.0      0.0  14.0  14.0  14.0
# 4  ...    4.0      3.0    2.0   1.0   2.0    5.0      0.0  11.0  13.0  13.0
#
# [5 rows x 33 columns]

# %%
strcols = ['school','sex','address','famsize','Pstatus','Mjob', 'Fjob', 'reason', 'guardian','schoolsup', 'famsup', 'paid', 'activities', 'nursery','higher', 'internet', 'romantic'] 
traindata[strcols] = traindata[strcols].astype(str)
testdata[strcols] = testdata[strcols].astype(str)
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    float64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    float64
#  7   Fedu        649 non-null    float64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    float64
#  13  studytime   649 non-null    float64
#  14  failures    649 non-null    float64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=0)

#xtrain = np.array(columnTransformer.fit_transform(xtrain),dtype=str)
#xtest = np.array(columnTransformer.fit_transform(xtest),dtype=str)

# %%
xtrain
# Out:
# array([['GP', 'F', 16.0, ..., 4.0, 9.0, 9.0],
#        ['MS', 'F', 18.0, ..., 3.0, 7.0, 8.0],
#        ['MS', 'F', 15.0, ..., 0.0, 9.0, 10.0],
#        ...,
#        ['GP', 'M', 16.0, ..., 2.0, 11.0, 12.0],
#        ['MS', 'M', 18.0, ..., 0.0, 12.0, 12.0],
#        ['GP', 'F', 15.0, ..., 0.0, 8.0, 7.0]], dtype=object)

# %%
for col in data.columns:
    print(col," : ", len(data[col].unique(),'')

# %%
regressor = LinearRegression()
regressor.fit(xtrain,ytrain)
ypred = regressor.predict(xtest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-6664e4d9d8b2> in <module>
#       1 regressor = LinearRegression()
# ----> 2 regressor.fit(xtrain,ytrain)
#       3 ypred = regressor.predict(xtest)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
# ...

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(xtrain,ytrain)
ypred = clf.predict(xtest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-2313d31ea726> in <module>
#       1 clf = DecisionTreeClassifier()
# ----> 2 clf = clf.fit(xtrain,ytrain)
#       3 ypred = clf.predict(xtest)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     896         """
#     897
# --> 898         super().fit(
#     899             X, y,
#     900             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
# ...

# %%
print('mean ablsolute error: ',metrics.mean_absolute_error(ytest,ypred))
print('mean quared error: ',metrics.mean_squared_error(ytest,ypred))
print('root mean quared error: ',np.sqrt(metrics.mean_squared_error(ytest,ypred)))
r2_score(ytest,regressor.predict(xtest))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-35c44c403984> in <module>
# ----> 1 print('mean ablsolute error: ',metrics.mean_absolute_error(ytest,ypred))
#       2 print('mean quared error: ',metrics.mean_squared_error(ytest,ypred))
#       3 print('root mean quared error: ',np.sqrt(metrics.mean_squared_error(ytest,ypred)))
#       4 r2_score(ytest,regressor.predict(xtest))
#
# NameError: name 'ypred' is not defined

# %%
traindata.head()
# Out:
#   school sex   age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  18.0       U     GT3       A   4.0   4.0  at_home   teacher
# 1     GP   F  17.0       U     GT3       T   1.0   1.0  at_home     other
# 2     GP   F  15.0       U     LE3       T   1.0   1.0  at_home     other
# 3     GP   F  15.0       U     GT3       T   4.0   2.0   health  services
# 4     GP   F  16.0       U     GT3       T   3.0   3.0    other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences    G1    G2    G3
# 0  ...    4.0      3.0    4.0   1.0   1.0    3.0      4.0   0.0  11.0  11.0
# 1  ...    5.0      3.0    3.0   1.0   1.0    3.0      2.0   9.0  11.0  11.0
# 2  ...    4.0      3.0    2.0   2.0   3.0    3.0      6.0  12.0  13.0  12.0
# 3  ...    3.0      2.0    2.0   1.0   1.0    5.0      0.0  14.0  14.0  14.0
# 4  ...    4.0      3.0    2.0   1.0   2.0    5.0      0.0  11.0  13.0  13.0
#
# [5 rows x 33 columns]
